# %%
from db import DB

db = DB(username="glamp", dbname="yhat", dbtype="postgres")
db
# Out:
# DB[postgres][localhost]:5432 > glamp@yhat

# %%
db.tables
# Out:
# Tables(administrable_role_authorizations=+------------------------+
# |administrable_role_authorizations|
# +--------------+---------+
# | Column       | Type    |
# +--------------+---------+
# | grantee      | varchar |
# | role_name    | varchar |
# | is_grantable | varchar |
# +--------------+---------+, applicable_roles=+------------------------+
# |    applicable_roles    |
# +--------------+---------+
# | Column       | Type    |
# +--------------+---------+
# | grantee      | varchar |
# | role_name    | varchar |
# | is_grantable | varchar |
# +--------------+---------+, attributes=+------------------------------------------+
# |                attributes                |
# +--------------------------------+---------+
# | Column                         | Type    |
# +--------------------------------+---------+
# | udt_catalog                    | varchar |
# | udt_schema                     | varchar |
# | udt_name                       | varchar |
# ...

# %%
db.tables.mt_s3_logs
# Out:
# +---------------------------------+
# |            mt_s3_logs           |
# +-----------------------+---------+
# | Column                | Type    |
# +-----------------------+---------+
# | bucket_owner          | varchar |
# | bucket                | varchar |
# | datetime              | varchar |
# | ip                    | varchar |
# | requestor_id          | varchar |
# | request_id            | varchar |
# | operation             | varchar |
# | key                   | varchar |
# | http_method_uri_proto | varchar |
# | http_status           | varchar |
# | s3_error              | varchar |
# | bytes_sent            | varchar |
# | object_size           | varchar |
# | total_time            | varchar |
# | turn_around_time      | varchar |
# | referer               | varchar |
# | user_agent            | varchar |
# | _id                   | int8    |
# +-----------------------+---------+

# %%
db.tables.mt_s3_logs.head()
# Out:
# /usr/local/lib/python2.7/site-packages/pandas/io/sql.py:1189: FutureWarning: read_frame is deprecated, use read_sql
#   warnings.warn("read_frame is deprecated, use read_sql", FutureWarning)
#    _id                                       bucket_owner     bucket  \
# 0    1  cf77fe33107978c68ebf91e44d101ec99ec75c3cba670e...  moontower
# 1    2  cf77fe33107978c68ebf91e44d101ec99ec75c3cba670e...  moontower
# 2    3  cf77fe33107978c68ebf91e44d101ec99ec75c3cba670e...  moontower
# 3    4  cf77fe33107978c68ebf91e44d101ec99ec75c3cba670e...  moontower
# 4    5  cf77fe33107978c68ebf91e44d101ec99ec75c3cba670e...  moontower
# 5    6  cf77fe33107978c68ebf91e44d101ec99ec75c3cba670e...  moontower
#
#                      datetime              ip requestor_id        request_id  \
# 0  02/Jul/2014:03:00:50 +0000   67.220.23.216            -  7B1A7A18ED378B43
# 1  02/Jul/2014:03:02:29 +0000  98.164.103.185            -  6DBB9A1AAAE41771
# ...

# %%
db.tables.parameters
# Out:
# +------------------------------------+
# |             parameters             |
# +--------------------------+---------+
# | Column                   | Type    |
# +--------------------------+---------+
# | specific_catalog         | varchar |
# | specific_schema          | varchar |
# | specific_name            | varchar |
# | ordinal_position         | int4    |
# | parameter_mode           | varchar |
# | is_result                | varchar |
# | as_locator               | varchar |
# | parameter_name           | varchar |
# | data_type                | varchar |
# | character_maximum_length | int4    |
# | character_octet_length   | int4    |
# | character_set_catalog    | varchar |
# | character_set_schema     | varchar |
# | character_set_name       | varchar |
# | collation_catalog        | varchar |
# | collation_schema         | varchar |
# | collation_name           | varchar |
# | numeric_precision        | int4    |
# | numeric_precision_radix  | int4    |
# ...

# %%
db.find_column("_id")
# Out:
# +------------------+-------------+------+
# | Table            | Column Name | Type |
# +------------------+-------------+------+
# | ga_data          |     _id     | int4 |
# | jobs             |     _id     | int4 |
# | mt_s3_logs       |     _id     | int8 |
# | mt_s3_logs_users |     _id     | int8 |
# | tmp_mt_model     |     _id     | int8 |
# | tracking         |     _id     | int4 |
# | users            |     _id     | int4 |
# +------------------+-------------+------+

# %%
db.find_table("mt*")
# Out:
# +------------------+----------------------------------------------------------------------------------+
# | Table            | Columns                                                                          |
# +------------------+----------------------------------------------------------------------------------+
# | mt_s3_logs       | bucket_owner, bucket, datetime, ip, requestor_id, request_id, operation, key, ht |
# |                  | tp_method_uri_proto, http_status, s3_error, bytes_sent, object_size, total_time, |
# |                  |  turn_around_time, referer, user_agent, _id                                      |
# | mt_s3_logs_users | _id, user_id                                                                     |
# +------------------+----------------------------------------------------------------------------------+
